# %% [markdown]
# ## READ ME FIRST
#
# This notebook produces a weekly release from the `develop` branch of Cytoscape.
#
# The weekly release consists of Install4j generated installers that can be put on a public server to be downloaded by testers. This script will NOT push any code changes or resources to GitHub or Nexus or update any additional resources like the manual or API docs.
#
# This notebook is configured for the build server on which it is run. Notes have been made where local environment variables have been set.
#
# Before starting this process, it is a good idea to Restart and Clear Output for this notebook's Kernel.

# %% [markdown]
# ### 1. Set up Build Environment
#
# This sets up the build environment, including Java and Maven versions, and the root directory of the build.

# %%
from subprocess import Popen, PIPE
import os
import shutil

# %% [markdown]
# Set the notebook directory. Note that this is system dependent.

# %%
NOTEBOOK_DIR = '/home/cybuilder/cytoscape-admin-scripts'

print(NOTEBOOK_DIR)
# Out:
# /home/cybuilder/cytoscape-admin-scripts

# %% [markdown]
# Set the Java environment. This is Java 11 for Cytoscape 3.8.0 and above.
#
# Note that this is system dependent, and may need to be changed to reflect the system's configuration.

# %%
# %env JAVA_HOME=/opt/jdk-17
# Out:
# env: JAVA_HOME=/opt/jdk-17

# %% [markdown]
# Set the MAVEN_HOME environment variable, as well as point the path to the correct Maven binaries.
#
# Note that this is system dependent and may need to be changed to reflect the system's configuration.

# %%
# %env MAVEN_HOME=/opt/maven
# %env PATH=/opt/jdk-17/bin:/opt/apache-maven-3.6.0/bin/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin
# Out:
# env: MAVEN_HOME=/opt/maven
# env: PATH=/opt/jdk-17/bin:/opt/apache-maven-3.6.0/bin/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin

# %% [markdown]
# Prepare the target directory and clone the cytoscape git repo.

# %%
print('Changing to directory: ' + NOTEBOOK_DIR)
os.chdir(NOTEBOOK_DIR)

# Point to build location (the directory to clone parent cytoscape into)
BUILD_PARENT_DIR = os.path.join(os.getcwd(), 'release-build')
if not os.path.exists(BUILD_PARENT_DIR):
    os.mkdir(BUILD_PARENT_DIR)
else:
    shutil.rmtree(BUILD_PARENT_DIR)
    os.mkdir(BUILD_PARENT_DIR)

os.chdir(BUILD_PARENT_DIR)
![[ -d cytoscape ]] || git clone https://github.com/cytoscape/cytoscape
CYTOSCAPE_ROOT_DIR = os.path.join(BUILD_PARENT_DIR, 'cytoscape')
CYTOSCAPE_DIR = os.path.join(CYTOSCAPE_ROOT_DIR, 'cytoscape')

def cd(directory=BUILD_PARENT_DIR, *subdirs):
    if subdirs:
        directory = os.path.join(directory, *subdirs)
    if os.getcwd() != directory:
        os.chdir(directory)
# Out:
# Changing to directory: /home/cybuilder/cytoscape-admin-scripts
# Cloning into 'cytoscape'...
# remote: Enumerating objects: 689, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 689 (delta 100), reused 138 (delta 79), pack-reused 529 (from 1)
# Receiving objects: 100% (689/689), 791.50 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (353/353), done.

# %%
STARTING_BRANCH = 'release/3.10.3'

# %% [markdown]
# ## 2. Pull the develop branch of Cytoscape
#
# Note that to execute the checkout step here, you will need to have set up an SSH key on this machine that does not use password validation, or else parts of the build will be stall when they require input.

# %%
cd(CYTOSCAPE_ROOT_DIR)
![[ -d cytoscape ]] || ./cy.sh init
cd(CYTOSCAPE_DIR)
# !./cy.sh run-all "git checkout {STARTING_BRANCH}"
# Out:
# Target directory =
# Cytoscape project will be cloned to: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape
# Cloning into 'cytoscape'...
# remote: Enumerating objects: 689, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 689 (delta 70), reused 95 (delta 54), pack-reused 577 (from 1)
# Receiving objects: 100% (689/689), 806.55 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (354/354), done.
# Cloning: parent (URI = git@github.com:cytoscape/cytoscape-parent.git)
# Cloning into 'parent'...
# remote: Enumerating objects: 1733, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 1733 (delta 61), reused 52 (delta 20), pack-reused 1640 (from 1)
# Receiving objects: 100% (1733/1733), 267.56 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (689/689), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/parent ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: api (URI = git@github.com:cytoscape/cytoscape-api.git)
# Cloning into 'api'...
# remote: Enumerating objects: 29094, done.
# remote: Counting objects: 100% (4105/4105), done.
# remote: Compressing objects: 100% (1596/1596), done.
# remote: Total 29094 (delta 1589), reused 4040 (delta 1533), pack-reused 24989 (from 1)
# Receiving objects: 100% (29094/29094), 6.91 MiB | 12.96 MiB/s, done.
# Resolving deltas: 100% (9720/9720), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/api ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: impl (URI = git@github.com:cytoscape/cytoscape-impl.git)
# Cloning into 'impl'...
# remote: Enumerating objects: 163545, done.
# remote: Counting objects: 100% (18371/18371), done.
# remote: Compressing objects: 100% (6355/6355), done.
# remote: Total 163545 (delta 7568), reused 18207 (delta 7442), pack-reused 145174 (from 1)
# Receiving objects: 100% (163545/163545), 196.22 MiB | 21.00 MiB/s, done.
# Resolving deltas: 100% (67550/67550), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/impl ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: support (URI = git@github.com:cytoscape/cytoscape-support.git)
# Cloning into 'support'...
# remote: Enumerating objects: 6325, done.
# remote: Counting objects: 100% (669/669), done.
# remote: Compressing objects: 100% (488/488), done.
# remote: Total 6325 (delta 233), reused 545 (delta 117), pack-reused 5656 (from 1)
# Receiving objects: 100% (6325/6325), 670.20 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (2152/2152), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/support ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: gui-distribution (URI = git@github.com:cytoscape/cytoscape-gui-distribution.git)
# Cloning into 'gui-distribution'...
# remote: Enumerating objects: 8283, done.
# remote: Counting objects: 100% (1819/1819), done.
# remote: Compressing objects: 100% (830/830), done.
# remote: Total 8283 (delta 851), reused 1738 (delta 787), pack-reused 6464 (from 1)
# Receiving objects: 100% (8283/8283), 89.44 MiB | 20.69 MiB/s, done.
# Resolving deltas: 100% (3493/3493), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: app-developer (URI = git@github.com:cytoscape/cytoscape-app-developer.git)
# Cloning into 'app-developer'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 316 (delta 23), reused 15 (delta 2), pack-reused 280 (from 1)
# Receiving objects: 100% (316/316), 36.66 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (157/157), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/app-developer ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# \n\n - Finished: here is the current status:\n
# ------------------------------------------------------------------------
# - .:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - parent:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - api:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - impl:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - support:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - gui-distribution:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - app-developer:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Executing command: git checkout release/3.10.3
# --in .
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------
# --in parent
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------
# --in api
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------
# --in impl
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------
# --in support
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------
# --in gui-distribution
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------
# --in app-developer
# Branch release/3.10.3 set up to track remote branch release/3.10.3 from origin.
# Switched to a new branch 'release/3.10.3'
# ------------------------------------------------------------------------

# %% [markdown]
# ## 2a. Reset

# %%
cd(CYTOSCAPE_DIR)
# !./cy.sh run-all 'git clean -f -d'
# !./cy.sh run-all 'git reset --hard'
# Out:
# ------------------------------------------------------------------------
# Executing command: git clean -f -d
# --in .
# ------------------------------------------------------------------------
# --in parent
# ------------------------------------------------------------------------
# --in api
# ------------------------------------------------------------------------
# --in impl
# ------------------------------------------------------------------------
# --in support
# ------------------------------------------------------------------------
# --in gui-distribution
# ------------------------------------------------------------------------
# --in app-developer
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Executing command: git reset --hard
# --in .
# HEAD is now at 2e34f92 Set version to 3.10.3
# ------------------------------------------------------------------------
# --in parent
# HEAD is now at 61fb71c Fixes the required taglets version (from 3.10.1 to 3.10.3)
# ------------------------------------------------------------------------
# --in api
# HEAD is now at 83e2701 Set version to 3.10.3
# ------------------------------------------------------------------------
# --in impl
# HEAD is now at d485972 Renames the Properties button to "More Properties" and changes the tooltips -- CYTOSCAPE-13128
# ------------------------------------------------------------------------
# --in support
# HEAD is now at c67f0d3 Set version to 3.10.3
# ------------------------------------------------------------------------
# --in gui-distribution
# HEAD is now at e7d1901 Bump Enrichment table core app to version 2.0.7
# ------------------------------------------------------------------------
# --in app-developer
# HEAD is now at 233c3fd Set version to 3.10.3
# ------------------------------------------------------------------------

# %% [markdown]
# ## 2. Verify status

# %%
cd(CYTOSCAPE_DIR)
# !./cy.sh run-all 'git status'
# Out:
# ------------------------------------------------------------------------
# Executing command: git status
# --in .
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in parent
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in api
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in impl
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in support
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in gui-distribution
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in app-developer
# # On branch release/3.10.3
# nothing to commit, working directory clean
# ------------------------------------------------------------------------

# %% [markdown]
# ## 3. Build Cytoscape and ensure no errors
#
# This may take a while. Expect to build subrepos first before building from the root directory
#
# Currently, you should expect two or so non-fatal javadoc-bundle-options related errors.

# %%
cd(CYTOSCAPE_DIR)
with open('build_output.txt', 'w') as outf:
    process = Popen('mvn clean install -Dmaven.test.skip=true'.split(' '), 
                stdout=outf,
                cwd=CYTOSCAPE_DIR)
    process.wait()

print("Showing ERROR lines in build...")
# !cat build_output.txt | grep ERROR
# Out:
# Showing ERROR lines in build...
# [ERROR] Error fetching link: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/api/app-api/target/javadoc-bundle-options. Ignored it.
# [ERROR] Error fetching link: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/api/swing-app-api/target/javadoc-bundle-options. Ignored it.

# %% [markdown]
# ## 4. Build Cytoscape installers
#
# This requires Install4J to be configured on your machine and for the Install4j project file to point to the correct Mac signing file. The keystore password is set below (blank in this config), to be interpreted by the Install4j Maven plugin.

# %%
cd(CYTOSCAPE_DIR, 'gui-distribution', 'packaging')
# %env MAC_KEYSTORE_PASSWORD=
# !mvn clean install -U
# Out:
# env: MAC_KEYSTORE_PASSWORD=
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for org.cytoscape.distribution:packaging:jar:3.10.3
# [WARNING] 'build.plugins.plugin.version' for org.sonatype.install4j:install4j-maven-plugin is missing. @ org.cytoscape.distribution:packaging:[unknown-version], /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/pom.xml, line 138, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ----------------< org.cytoscape.distribution:packaging >----------------
# [INFO] Building Cytoscape Release Packaging 3.10.3
# [INFO] --------------------------------[ jar ]---------------------------------
# Downloading from cytoscape_snapshots: http://nrnb-nexus.ucsd.edu/repository/cytoscape_snapshots/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloading from cytoscape_releases: http://nrnb-nexus.ucsd.edu/repository/cytoscape_releases/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloading from cytoscape_thirdparty: http://nrnb-nexus.ucsd.edu/repository/cytoscape_thirdparty/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml (690 B at 2.4 kB/s)
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ packaging ---
# [INFO]
# [INFO] --- maven-dependency-plugin:3.3.0:unpack-dependencies (unpack-javadoc) @ packaging ---
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ packaging ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Copying 1 resource
# [INFO] Copying 15 resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.0:compile (default-compile) @ packaging ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ packaging ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.0:testCompile (default-testCompile) @ packaging ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:3.0.0-M3:test (default-test) @ packaging ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ packaging ---
# [INFO] Building jar: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.10.3.jar
# [INFO]
# [INFO] >>> maven-source-plugin:3.0.1:jar (attach-sources) > generate-sources @ packaging >>>
# [INFO]
# [INFO] <<< maven-source-plugin:3.0.1:jar (attach-sources) < generate-sources @ packaging <<<
# [INFO]
# [INFO]
# [INFO] --- maven-source-plugin:3.0.1:jar (attach-sources) @ packaging ---
# [INFO] Building jar: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.10.3-sources.jar
# [INFO]
# [INFO] --- maven-dependency-plugin:3.3.0:copy-dependencies (copy-dependencies) @ packaging ---
# [INFO] Copying cytoscape-3.10.3.zip to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/bundles/cytoscape-3.10.3.zip
# [INFO] Copying cytoscape-3.10.3.tar.gz to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/bundles/cytoscape-3.10.3.tar.gz
# [INFO]
# [INFO] --- maven-dependency-plugin:3.3.0:unpack (unpack) @ packaging ---
# [INFO] Configured Artifact: org.cytoscape.distribution:cytoscape:3.10.3:zip
# [INFO] Configured Artifact: org.cytoscape.distribution:cytoscape:3.10.3:tar.gz
# [INFO] Unpacking /home/cybuilder/.m2/repository/org/cytoscape/distribution/cytoscape/3.10.3/cytoscape-3.10.3.zip to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target with includes "" and excludes ""
# [INFO] Unpacking /home/cybuilder/.m2/repository/org/cytoscape/distribution/cytoscape/3.10.3/cytoscape-3.10.3.tar.gz to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target with includes "" and excludes ""
# [INFO] Expanding: /home/cybuilder/.m2/repository/org/cytoscape/distribution/cytoscape/3.10.3/cytoscape-3.10.3.tar.gz into /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target
# [INFO]
# [INFO] --- install4j-maven-plugin:1.1.2:compile (compile-installers) @ packaging ---
# [INFO] chmod: changing permissions of ‘/opt/install4j10/bin/install4jc’: Operation not permitted
# [ERROR] Result: 1
# [INFO] install4j version 10.0.4 (build 10066), built on 2022-11-28
# [INFO] Registered to
# [INFO]
# [INFO] Loading config file /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/classes/Cytoscape.install4j
# [INFO] [WARNING] A JDK release was configured on the "General Settings->JRE Bundles" step, but no media file uses a generated JRE bundle.
# [INFO] [WARNING] The JDK with name "" has not been configured in this install4j installation (config file /home/cybuilder/.config/install4j/v10/config.xml).
# [INFO]           As a fallback, a suitable JDK will be downloaded with the settings from the "General Settings->JRE Bundles" step.
# [INFO] Creating media file 'windows':
# [INFO] Created media file output directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]   Creating media file:
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Creating media file 'macos x64':
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]       Signing launcher
# [INFO]   Creating media file:
# [INFO]     Signing launcher
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Creating media file 'macos aarch64':
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]       Signing launcher
# [INFO]   Creating media file:
# [INFO]     Signing launcher
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Creating media file 'unix':
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]       Generating launcher script file
# [INFO]   Creating media file:
# [INFO]     Generating launcher script file
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Compressing 4 media files with 4 threads:
# [INFO]
# [INFO] Compressed media file 'unix':
# [INFO]   Compressing files
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_10_3_unix.sh.
# [INFO]   The size of the media file is 229.4 MB
# [INFO]
# [INFO] Compressed media file 'windows':
# [INFO]   Compressing files
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_10_3_windows_64bit.exe.
# [INFO]   The size of the media file is 223.5 MB
# [INFO]
# [INFO]   Important: Please make sure that the file
# [INFO]       /home/cybuilder/.local/share/install4j/v10/jres/windows-amd64-17.0.5.tar.gz
# [INFO]   can be downloaded from
# [INFO]       https://cytoscape-builds.ucsd.edu/jres/windows-amd64-17.0.5.tar.gz
# [INFO]
# [INFO] Compressed media file 'macos aarch64':
# [INFO]   Compressing files
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-base-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-graphics-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Signing /libprism_sw.dylib
# [INFO]   Signing /libdecora_sse.dylib
# [INFO]   Signing /libprism_es2.dylib
# [INFO]   Signing /libprism_common.dylib
# [INFO]   Signing /libjavafx_font.dylib
# [INFO]   Signing /libglass.dylib
# [INFO]   Signing /libjavafx_iio.dylib
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-media-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Signing /libjfxmedia.dylib
# [INFO]   Signing /libgstreamer-lite.dylib
# [INFO]   Signing /libfxplugins.dylib
# [INFO]   Signing /libglib-lite.dylib
# [INFO]   Signing /libjfxmedia_avf.dylib
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-web-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Signing /libjfxwebkit.dylib
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-fxml-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-swing-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Searching .i4j_external_641/framework/lib/openjfx/mac_aarch64/javafx-controls-22.0.2-mac-aarch64.jar for binaries
# [INFO]   Generating VM options file vmoptions.txt.
# [INFO]   Signing libi4jinst.dylib
# [INFO]   Signing libi4jinst2.dylib
# [INFO]   Signing install4j
# [INFO]   Signing installer
# [INFO]   Signing DMG
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_10_3_macos_aarch64.dmg.
# [INFO]   The size of the media file is 222.1 MB
# [INFO]
# [INFO]   Important: Please make sure that the file
# [INFO]       /home/cybuilder/.local/share/install4j/v10/jres/macos-aarch64-17.0.5.tar.gz
# [INFO]   can be downloaded from
# [INFO]       https://cytoscape-builds.ucsd.edu/jres/macos-aarch64-17.0.5.tar.gz
# [INFO]
# [INFO] Compressed media file 'macos x64':
# [INFO]   Compressing files
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-controls-22.0.2-mac.jar for binaries
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-base-22.0.2-mac.jar for binaries
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-fxml-22.0.2-mac.jar for binaries
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-web-22.0.2-mac.jar for binaries
# [INFO]   Signing /libjfxwebkit.dylib
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-swing-22.0.2-mac.jar for binaries
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-media-22.0.2-mac.jar for binaries
# [INFO]   Signing /libjfxmedia.dylib
# [INFO]   Signing /libgstreamer-lite.dylib
# [INFO]   Signing /libfxplugins.dylib
# [INFO]   Signing /libglib-lite.dylib
# [INFO]   Signing /libjfxmedia_avf.dylib
# [INFO]   Searching .i4j_external_639/framework/lib/openjfx/mac/javafx-graphics-22.0.2-mac.jar for binaries
# [INFO]   Signing /libprism_sw.dylib
# [INFO]   Signing /libdecora_sse.dylib
# [INFO]   Signing /libprism_es2.dylib
# [INFO]   Signing /libprism_common.dylib
# [INFO]   Signing /libjavafx_font.dylib
# [INFO]   Signing /libglass.dylib
# [INFO]   Signing /libjavafx_iio.dylib
# [INFO]   Generating VM options file vmoptions.txt.
# [INFO]   Signing libi4jinst.dylib
# [INFO]   Signing libi4jinst2.dylib
# [INFO]   Signing install4j
# [INFO]   Signing installer
# [INFO]   Signing DMG
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_10_3_macos_x64.dmg.
# [INFO]   The size of the media file is 224.5 MB
# [INFO]
# [INFO]   Important: Please make sure that the file
# [INFO]       /home/cybuilder/.local/share/install4j/v10/jres/macos-amd64-17.0.5.tar.gz
# [INFO]   can be downloaded from
# [INFO]       https://cytoscape-builds.ucsd.edu/jres/macos-amd64-17.0.5.tar.gz
# [INFO]
# [INFO] Important: macOS media sets have to be notarized before distribution.
# [INFO]   More information in the code signing help.
# [INFO]
# [INFO] Writing md5sums.
# [INFO] Writing sha256sums.
# [INFO] Writing updates.xml.
# [INFO] Build completed in 58.2 seconds at 2024-09-27 11:28:17 with 2 warnings.
# [INFO] Run the build in verbose mode to get instructions on how to suppress selected warnings.
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ packaging ---
# [INFO] Installing /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.10.3.jar to /home/cybuilder/.m2/repository/org/cytoscape/distribution/packaging/3.10.3/packaging-3.10.3.jar
# [INFO] Installing /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/pom.xml to /home/cybuilder/.m2/repository/org/cytoscape/distribution/packaging/3.10.3/packaging-3.10.3.pom
# [INFO] Installing /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.10.3-sources.jar to /home/cybuilder/.m2/repository/org/cytoscape/distribution/packaging/3.10.3/packaging-3.10.3-sources.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  01:09 min
# [INFO] Finished at: 2024-09-27T11:28:18-07:00
# [INFO] ------------------------------------------------------------------------

# %% [markdown]
# ## 5. Copying Cytoscape installers to weekly download page
#
# When completed installer executables can be found in `cytoscape/cytoscape/gui-distribution/packaging/target/media` and compressed builds for Linux and Windows can be found in `cytoscape/cytoscape/gui-distribution/assembly/target`
#
# all of which should be copied to `/var/www/html/cytoscape-builds/Cytoscape-3.9.0/<DATE>`

# %%
# !mkdir -p /var/www/html/cytoscape-builds/Cytoscape-3.10.3/rc1
# !rsync -av --progress /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media/* /var/www/html/cytoscape-builds/Cytoscape-3.10.3/rc1
# !rsync -av --progress /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/assembly/target/*.{gz,zip} /var/www/html/cytoscape-builds/Cytoscape-3.10.3/rc1
# Out:
# sending incremental file list
# Cytoscape_3_10_3_macos_aarch64.dmg
#     232,908,120 100%  204.50MB/s    0:00:01 (xfr#1, to-chk=7/8)
# Cytoscape_3_10_3_macos_x64.dmg
#     235,431,252 100%  240.91MB/s    0:00:00 (xfr#2, to-chk=6/8)
# Cytoscape_3_10_3_unix.sh
#     240,503,020 100%  142.11MB/s    0:00:01 (xfr#3, to-chk=5/8)
# Cytoscape_3_10_3_windows_64bit.exe
#     234,318,848 100%  179.34MB/s    0:00:01 (xfr#4, to-chk=4/8)
# md5sums
#             262 100%    1.04kB/s    0:00:00 (xfr#5, to-chk=3/8)
# output.txt
#             776 100%    3.07kB/s    0:00:00 (xfr#6, to-chk=2/8)
# sha256sums
#             390 100%    1.54kB/s    0:00:00 (xfr#7, to-chk=1/8)
# updates.xml
#           1,678 100%    6.63kB/s    0:00:00 (xfr#8, to-chk=0/8)
#
# sent 943,395,185 bytes  received 168 bytes  209,643,411.78 bytes/sec
# total size is 943,164,346  speedup is 1.00
# sending incremental file list
# cytoscape-unix-3.10.3.tar.gz
#     361,168,407 100%  283.23MB/s    0:00:01 (xfr#1, to-chk=1/2)
# cytoscape-windows-3.10.3.zip
#     362,249,326 100%  249.80MB/s    0:00:01 (xfr#2, to-chk=0/2)
#
# sent 723,594,543 bytes  received 54 bytes  289,437,838.80 bytes/sec
# total size is 723,417,733  speedup is 1.00

# %% [markdown]
# ## 6. Notarizing on idekerlab-macmini
#
# The install4j generated .dmg must be notarized to run on macOS 10.15 and above. The .dmg will be sent to idekerlab-macmini and submitted for notarization. An email will be sent to William Markuske when the notarization process is complete. As soon as the .dmg is notarized it will work and no further action is needed.

# %%
#!rsync -av --progress /var/www/html/cytoscape-builds/Cytoscape-3.9.0/$(date +%Y_%m_%d)/*.dmg idekerlab@idekerlab-macmini.ucsd.edu:~/apps_to_notarize/
#!ssh idekerlab@idekerlab-macmini.ucsd.edu '~/notarizedmg_jing.sh ~/apps_to_notarize/*.dmg Snapshot.$(date +%Y%m%d)'
# Out:
# building file list ...
# 1 file to consider
# Cytoscape_3_9_0-SNAPSHOT_macos.dmg
#     292,894,009 100%   84.61MB/s    0:00:03 (xfr#1, to-chk=0/1)
#
# sent 292,929,916 bytes  received 46 bytes  65,095,547.11 bytes/sec
# total size is 292,894,009  speedup is 1.00
# No errors uploading '/Users/idekerlab/apps_to_notarize/Cytoscape_3_9_0-SNAPSHOT_macos.dmg'.
# RequestUUID = 6a41ff2a-9fd8-43d6-b378-adfd075b613b

# %% [markdown]
# You can check the status of the notarization by pasting in the `RequestUUID` value into the following command and running.

# %%
#!ssh idekerlab@idekerlab-macmini.ucsd.edu '~/notarizestatus_jing.sh 6a41ff2a-9fd8-43d6-b378-adfd075b613b'
# Out:
# No errors getting notarization info.
#
#           Date: 2021-04-30 13:56:52 +0000
#           Hash: 7d32053845cd00b39f1a454710f3a650974f7f5d980ea41753a515efb27ee8cc
#     LogFileURL: https://osxapps-ssl.itunes.apple.com/itunes-assets/Enigma115/v4/91/1f/c3/911fc3d0-a26b-067b-633c-b9cc8ce3e71a/developer_log.json?accessKey=1619985924_8906453629669302967_JpRk3DbwQdUPeY0fjgXAfuB0rVc%2FQkGm0wHltInIzu7k9XgkuwZmK3DtsDmyD%2FHD%2FAP1BLjqG%2BlEIEvOJNlbOcYPq%2FKsH%2B5LfUd%2Byja0avqDGmZ15ZgRo4Rp9sOJYsf%2Fv8PydAzkQSHl9NQDC8CfSUg%2BE1%2Fpw47CEbwJpnrmmfQ%3D
#    RequestUUID: 6a41ff2a-9fd8-43d6-b378-adfd075b613b
#         Status: success
#    Status Code: 0
# Status Message: Package Approved
