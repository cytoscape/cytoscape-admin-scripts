# %% [markdown]
# ## READ ME FIRST
#
# This notebook produces a weekly release from the `develop` branch of Cytoscape.
#
# The weekly release consists of Install4j generated installers that can be put on a public server to be downloaded by testers. This script will NOT push any code changes or resources to GitHub or Nexus or update any additional resources like the manual or API docs.
#
# This notebook is configured for the build server on which it is run. Notes have been made where local environment variables have been set.
#
# Before starting this process, it is a good idea to Restart and Clear Output for this notebook's Kernel.

# %% [markdown]
# ### 1. Set up Build Environment
#
# This sets up the build environment, including Java and Maven versions, and the root directory of the build.

# %%
from subprocess import Popen, PIPE
import os
import shutil

# %% [markdown]
# Set the notebook directory. Note that this is system dependent.

# %%
NOTEBOOK_DIR = '/home/cybuilder/cytoscape-admin-scripts'

print(NOTEBOOK_DIR)
# Out:
# /home/cybuilder/cytoscape-admin-scripts

# %% [markdown]
# Set the Java environment. This is Java 11 for Cytoscape 3.8.0 and above.
#
# Note that this is system dependent, and may need to be changed to reflect the system's configuration.

# %%
# %env JAVA_HOME=/usr/lib/jvm/jre-11-openjdk
# Out:
# env: JAVA_HOME=/usr/lib/jvm/jre-11-openjdk

# %% [markdown]
# Set the MAVEN_HOME environment variable, as well as point the path to the correct Maven binaries.
#
# Note that this is system dependent and may need to be changed to reflect the system's configuration.

# %%
# %env MAVEN_HOME=/opt/maven
# %env PATH=/opt/apache-maven-3.6.0/bin/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin
# Out:
# env: MAVEN_HOME=/opt/maven
# env: PATH=/opt/apache-maven-3.6.0/bin/:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin

# %% [markdown]
# Prepare the target directory and clone the cytoscape git repo.

# %%
print('Changing to directory: ' + NOTEBOOK_DIR)
os.chdir(NOTEBOOK_DIR)

# Point to build location (the directory to clone parent cytoscape into)
BUILD_PARENT_DIR = os.path.join(os.getcwd(), 'release-build')
if not os.path.exists(BUILD_PARENT_DIR):
    os.mkdir(BUILD_PARENT_DIR)
else:
    shutil.rmtree(BUILD_PARENT_DIR)
    os.mkdir(BUILD_PARENT_DIR)

os.chdir(BUILD_PARENT_DIR)
![[ -d cytoscape ]] || git clone https://github.com/cytoscape/cytoscape
CYTOSCAPE_ROOT_DIR = os.path.join(BUILD_PARENT_DIR, 'cytoscape')
CYTOSCAPE_DIR = os.path.join(CYTOSCAPE_ROOT_DIR, 'cytoscape')

def cd(directory=BUILD_PARENT_DIR, *subdirs):
    if subdirs:
        directory = os.path.join(directory, *subdirs)
    if os.getcwd() != directory:
        os.chdir(directory)
# Out:
# Changing to directory: /home/cybuilder/cytoscape-admin-scripts
# Cloning into 'cytoscape'...
# remote: Enumerating objects: 607, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 607 (delta 45), reused 58 (delta 29), pack-reused 529
# Receiving objects: 100% (607/607), 774.64 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (298/298), done.

# %%
STARTING_BRANCH = 'release/3.9.0'     # develop for major release, release/3.X.X for minor release

# %% [markdown]
# ## 2. Pull the develop branch of Cytoscape
#
# Note that to execute the checkout step here, you will need to have set up an SSH key on this machine that does not use password validation, or else parts of the build will be stall when they require input.

# %%
cd(CYTOSCAPE_ROOT_DIR)
![[ -d cytoscape ]] || ./cy.sh init
cd(CYTOSCAPE_DIR)
# !./cy.sh run-all "git checkout {STARTING_BRANCH}"
# Out:
# Target directory =
# Cytoscape project will be cloned to: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape
# Cloning into 'cytoscape'...
# remote: Enumerating objects: 607, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 607 (delta 16), reused 13 (delta 3), pack-reused 577
# Receiving objects: 100% (607/607), 779.09 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (300/300), done.
# Cloning: parent (URI = git@github.com:cytoscape/cytoscape-parent.git)
# Cloning into 'parent'...
# remote: Enumerating objects: 1664, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 1664 (delta 14), reused 15 (delta 6), pack-reused 1640
# Receiving objects: 100% (1664/1664), 260.09 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (642/642), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/parent ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: api (URI = git@github.com:cytoscape/cytoscape-api.git)
# Cloning into 'api'...
# remote: Enumerating objects: 28105, done.
# remote: Counting objects: 100% (3050/3050), done.
# remote: Compressing objects: 100% (1417/1417), done.
# remote: Total 28105 (delta 1141), reused 2714 (delta 822), pack-reused 25055
# Receiving objects: 100% (28105/28105), 6.77 MiB | 11.39 MiB/s, done.
# Resolving deltas: 100% (9297/9297), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/api ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: impl (URI = git@github.com:cytoscape/cytoscape-impl.git)
# Cloning into 'impl'...
# remote: Enumerating objects: 154332, done.
# remote: Counting objects: 100% (9043/9043), done.
# remote: Compressing objects: 100% (3798/3798), done.
# remote: Total 154332 (delta 3480), reused 8600 (delta 3060), pack-reused 145289
# Receiving objects: 100% (154332/154332), 194.93 MiB | 19.91 MiB/s, done.
# Resolving deltas: 100% (63511/63511), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/impl ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: support (URI = git@github.com:cytoscape/cytoscape-support.git)
# Cloning into 'support'...
# remote: Enumerating objects: 5850, done.
# remote: Counting objects: 100% (194/194), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 5850 (delta 63), reused 147 (delta 26), pack-reused 5656
# Receiving objects: 100% (5850/5850), 621.21 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (1982/1982), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/support ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: gui-distribution (URI = git@github.com:cytoscape/cytoscape-gui-distribution.git)
# Cloning into 'gui-distribution'...
# remote: Enumerating objects: 7215, done.
# remote: Counting objects: 100% (751/751), done.
# remote: Compressing objects: 100% (529/529), done.
# remote: Total 7215 (delta 337), reused 492 (delta 133), pack-reused 6464
# Receiving objects: 100% (7215/7215), 65.43 MiB | 25.58 MiB/s, done.
# Resolving deltas: 100% (2979/2979), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Cloning: app-developer (URI = git@github.com:cytoscape/cytoscape-app-developer.git)
# Cloning into 'app-developer'...
# remote: Enumerating objects: 289, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 289 (delta 4), reused 5 (delta 0), pack-reused 280
# Receiving objects: 100% (289/289), 34.43 KiB | 0 bytes/s, done.
# Resolving deltas: 100% (138/138), done.
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/app-developer ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# Already on 'develop'
# ~/cytoscape-admin-scripts/release-build/cytoscape/cytoscape
# \n\n - Finished: here is the current status:\n
# ------------------------------------------------------------------------
# - .:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - parent:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - api:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - impl:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - support:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - gui-distribution:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# - app-developer:
#
# # On branch develop
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Executing command: git checkout release/3.9.0
# --in .
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------
# --in parent
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------
# --in api
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------
# --in impl
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------
# --in support
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------
# --in gui-distribution
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------
# --in app-developer
# Branch release/3.9.0 set up to track remote branch release/3.9.0 from origin.
# Switched to a new branch 'release/3.9.0'
# ------------------------------------------------------------------------

# %% [markdown]
# ## 2a. Reset

# %%
cd(CYTOSCAPE_DIR)
# !./cy.sh run-all 'git clean -f -d'
# !./cy.sh run-all 'git reset --hard'
# Out:
# ------------------------------------------------------------------------
# Executing command: git clean -f -d
# --in .
# ------------------------------------------------------------------------
# --in parent
# ------------------------------------------------------------------------
# --in api
# ------------------------------------------------------------------------
# --in impl
# ------------------------------------------------------------------------
# --in support
# ------------------------------------------------------------------------
# --in gui-distribution
# ------------------------------------------------------------------------
# --in app-developer
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Executing command: git reset --hard
# --in .
# HEAD is now at 12da7e6 Create 3.9.0 release branch.
# ------------------------------------------------------------------------
# --in parent
# HEAD is now at 109be3c Create 3.9.0 release branch.
# ------------------------------------------------------------------------
# --in api
# HEAD is now at 25cd928 Create 3.9.0 release branch.
# ------------------------------------------------------------------------
# --in impl
# HEAD is now at b232670 CYTOSCAPE-12898 Fix annotation API: color, fontstyle and opacity values.
# ------------------------------------------------------------------------
# --in support
# HEAD is now at 7ef82a0 Create 3.9.0 release branch.
# ------------------------------------------------------------------------
# --in gui-distribution
# HEAD is now at 15ae36b fixed sessions files: styles and thumbnails
# ------------------------------------------------------------------------
# --in app-developer
# HEAD is now at 4e23155 Create 3.9.0 release branch.
# ------------------------------------------------------------------------

# %% [markdown]
# ## 2. Verify status

# %%
cd(CYTOSCAPE_DIR)
# !./cy.sh run-all 'git status'
# Out:
# ------------------------------------------------------------------------
# Executing command: git status
# --in .
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in parent
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in api
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in impl
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in support
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in gui-distribution
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------
# --in app-developer
# # On branch release/3.9.0
# nothing to commit, working directory clean
# ------------------------------------------------------------------------

# %% [markdown]
# ## 3. Build Cytoscape and ensure no errors
#
# This may take a while. Expect to build subrepos first before building from the root directory
#
# Currently, you should expect two or so non-fatal javadoc-bundle-options related errors.

# %%
cd(CYTOSCAPE_DIR)
with open('build_output.txt', 'w') as outf:
    process = Popen('mvn clean install -Dmaven.test.skip=true'.split(' '), 
                stdout=outf,
                cwd=CYTOSCAPE_DIR)
    process.wait()

print("Showing ERROR lines in build...")
# !cat build_output.txt | grep ERROR
# Out:
# Showing ERROR lines in build...
# [ERROR] Error fetching link: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/api/app-api/target/javadoc-bundle-options. Ignored it.
# [ERROR] Error fetching link: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/api/swing-app-api/target/javadoc-bundle-options. Ignored it.

# %% [markdown]
# ## 4. Build Cytoscape installers
#
# This requires Install4J to be configured on your machine and for the Install4j project file to point to the correct Mac signing file. The keystore password is set below (blank in this config), to be interpreted by the Install4j Maven plugin.

# %%
cd(CYTOSCAPE_DIR, 'gui-distribution', 'packaging')
# %env MAC_KEYSTORE_PASSWORD=
# !mvn clean install -U
# Out:
# env: MAC_KEYSTORE_PASSWORD=
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for org.cytoscape.distribution:packaging:jar:3.9.0
# [WARNING] 'build.plugins.plugin.version' for org.sonatype.install4j:install4j-maven-plugin is missing. @ org.cytoscape.distribution:packaging:[unknown-version], /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/pom.xml, line 104, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ----------------< org.cytoscape.distribution:packaging >----------------
# [INFO] Building Cytoscape Release Packaging 3.9.0
# [INFO] --------------------------------[ jar ]---------------------------------
# Downloading from cytoscape_releases: http://nrnb-nexus.ucsd.edu/repository/cytoscape_releases/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloading from cytoscape_thirdparty: http://nrnb-nexus.ucsd.edu/repository/cytoscape_thirdparty/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloading from central: https://repo.maven.apache.org/maven2/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloading from cytoscape_snapshots: http://nrnb-nexus.ucsd.edu/repository/cytoscape_snapshots/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml
# Downloaded from central: https://repo.maven.apache.org/maven2/org/sonatype/install4j/install4j-maven-plugin/maven-metadata.xml (690 B at 2.2 kB/s)
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ packaging ---
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack-dependencies (unpack-distribution) @ packaging ---
# [INFO] Unpacking /home/cybuilder/.m2/repository/org/cytoscape/distribution/cytoscape/3.9.0/cytoscape-3.9.0.zip to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target with includes "" and excludes ""
# [INFO] Unpacking /home/cybuilder/.m2/repository/org/cytoscape/distribution/cytoscape/3.9.0/cytoscape-3.9.0.tar.gz to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target with includes "" and excludes ""
# [INFO] Expanding: /home/cybuilder/.m2/repository/org/cytoscape/distribution/cytoscape/3.9.0/cytoscape-3.9.0.tar.gz into /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:unpack-dependencies (unpack-javadoc) @ packaging ---
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:copy-dependencies (copy-distribution) @ packaging ---
# [INFO] Copying cytoscape-3.9.0.zip to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/install4j/cytoscape-3.9.0.zip
# [INFO] Copying cytoscape-3.9.0.tar.gz to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/install4j/cytoscape-3.9.0.tar.gz
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ packaging ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Copying 2 resources
# [INFO] Copying 7 resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.0:compile (default-compile) @ packaging ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ packaging ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.8.0:testCompile (default-testCompile) @ packaging ---
# [INFO] No sources to compile
# [INFO]
# [INFO] --- maven-surefire-plugin:3.0.0-M3:test (default-test) @ packaging ---
# [INFO] No tests to run.
# [INFO]
# [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ packaging ---
# [INFO] Building jar: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.9.0.jar
# [INFO]
# [INFO] >>> maven-source-plugin:3.0.1:jar (attach-sources) > generate-sources @ packaging >>>
# [INFO]
# [INFO] <<< maven-source-plugin:3.0.1:jar (attach-sources) < generate-sources @ packaging <<<
# [INFO]
# [INFO]
# [INFO] --- maven-source-plugin:3.0.1:jar (attach-sources) @ packaging ---
# [INFO] Building jar: /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.9.0-sources.jar
# [INFO]
# [INFO] --- maven-dependency-plugin:3.1.1:copy-dependencies (copy-dependencies) @ packaging ---
# [INFO] Copying cytoscape-3.9.0.zip to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/bundles/cytoscape-3.9.0.zip
# [INFO] Copying cytoscape-3.9.0.tar.gz to /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/bundles/cytoscape-3.9.0.tar.gz
# [INFO]
# [INFO] --- install4j-maven-plugin:1.1.2:compile (compile-installers) @ packaging ---
# [INFO] chmod: changing permissions of ‘/opt/install4j8/bin/install4jc’: Operation not permitted
# [ERROR] Result: 1
# [INFO] install4j version 8.0.2 (build 8057), built on 2019-09-25
# [INFO] Using Java 11.0.4 from /usr/lib/jvm/java-11-openjdk-11.0.4.11-1.el7_7.x86_64
# [INFO] Registered to Cytoscape Builder, Cytoscape Consortium
# [INFO]
# [INFO] Loading config file /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/classes/Cytoscape.install4j
# [INFO] Creating media file 'Windows 64 bit':
# [INFO] Created media file output directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]   Creating media file:
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Creating media file 'Windows 32 bit':
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]   Creating media file:
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Creating media file 'Mac OS X':
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]       Signing launcher
# [INFO]   Creating media file:
# [INFO]     Signing launcher
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Creating media file 'Unix':
# [INFO]   Collecting files:
# [INFO]   Compiling launchers:
# [INFO]     Compiling launcher 'Cytoscape':
# [INFO]       Generating launcher script file
# [INFO]   Creating media file:
# [INFO]     Generating launcher script file
# [INFO]     Zipping custom code & resources JAR file
# [INFO]     Identifying components
# [INFO]     Shrinking runtime
# [INFO]
# [INFO] Compressing 4 media files with 4 threads:
# [INFO]
# [INFO] Compressed media file 'Unix':
# [INFO]   Compressing files
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_9_0_unix.sh.
# [INFO]   The size of the media file is 273.5 MB
# [INFO]
# [INFO] Compressed media file 'Windows 32 bit':
# [INFO]   Compressing files
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_9_0_windows_32bit.exe.
# [INFO]   The size of the media file is 275.1 MB
# [INFO]
# [INFO] Compressed media file 'Windows 64 bit':
# [INFO]   Compressing files
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_9_0_windows_64bit.exe.
# [INFO]   The size of the media file is 275.2 MB
# [INFO]
# [INFO]   Important: Please make sure that the file
# [INFO]       /home/cybuilder/.install4j8/jres/windows-amd64-11.0.6.tar.gz
# [INFO]   can be downloaded from
# [INFO]       https://cytoscape-builds.ucsd.edu/jres/windows-amd64-11.0.6.tar.gz
# [INFO]
# [INFO] Compressed media file 'Mac OS X':
# [INFO]   Compressing files
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-base-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-controls-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-swing-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-graphics-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-media-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-fxml-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/linux/javafx-web-15.0.1-linux.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-web-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-swing-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-graphics-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-media-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-base-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-controls-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/win/javafx-fxml-15.0.1-win.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-media-15.0.1-mac.jar for binaries
# [INFO]   Signing /libjfxmedia.dylib
# [INFO]   Signing /libgstreamer-lite.dylib
# [INFO]   Signing /libfxplugins.dylib
# [INFO]   Signing /libglib-lite.dylib
# [INFO]   Signing /libjfxmedia_avf.dylib
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-base-15.0.1-mac.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-graphics-15.0.1-mac.jar for binaries
# [INFO]   Signing /libprism_sw.dylib
# [INFO]   Signing /libdecora_sse.dylib
# [INFO]   Signing /libprism_es2.dylib
# [INFO]   Signing /libprism_common.dylib
# [INFO]   Signing /libjavafx_font.dylib
# [INFO]   Signing /libglass.dylib
# [INFO]   Signing /libjavafx_iio.dylib
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-controls-15.0.1-mac.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-web-15.0.1-mac.jar for binaries
# [INFO]   Signing /libjfxwebkit.dylib
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-fxml-15.0.1-mac.jar for binaries
# [INFO]   Searching .i4j_external_228/framework/lib/openjfx/mac/javafx-swing-15.0.1-mac.jar for binaries
# [INFO]   Generating VM options file vmoptions.txt.
# [INFO]   Signing libi4jinst2.dylib
# [INFO]   Signing install4j
# [INFO]   Signing libi4jinst.dylib
# [INFO]   Signing installer
# [INFO]   Signing DMG
# [INFO]   Moving media files to media directory /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media
# [INFO]   The name of the media file is Cytoscape_3_9_0_macos.dmg.
# [INFO]   The size of the media file is 275.5 MB
# [INFO]
# [INFO]   Important: Please make sure that the file
# [INFO]       /home/cybuilder/.install4j8/jres/macosx-amd64-11.0.6.tar.gz
# [INFO]   can be downloaded from
# [INFO]       https://cytoscape-builds.ucsd.edu/jres/macosx-amd64-11.0.6.tar.gz
# [INFO]
# [INFO] Important: macOS media sets have to be notarized before distribution.
# [INFO]   More information in the code signing help.
# [INFO]
# [INFO] Writing md5sums.
# [INFO] Writing sha256sums.
# [INFO] Writing updates.xml.
# [INFO] Build completed in 67.7 seconds.
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ packaging ---
# [INFO] Installing /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.9.0.jar to /home/cybuilder/.m2/repository/org/cytoscape/distribution/packaging/3.9.0/packaging-3.9.0.jar
# [INFO] Installing /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/pom.xml to /home/cybuilder/.m2/repository/org/cytoscape/distribution/packaging/3.9.0/packaging-3.9.0.pom
# [INFO] Installing /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/packaging-3.9.0-sources.jar to /home/cybuilder/.m2/repository/org/cytoscape/distribution/packaging/3.9.0/packaging-3.9.0-sources.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  01:23 min
# [INFO] Finished at: 2021-09-29T11:01:07-07:00
# [INFO] ------------------------------------------------------------------------

# %% [markdown]
# ## 5. Copying Cytoscape installers to weekly download page
#
# When completed installer executables can be found in `cytoscape/cytoscape/gui-distribution/packaging/target/media` and compressed builds for Linux and Windows can be found in `cytoscape/cytoscape/gui-distribution/assembly/target`
#
# all of which should be copied to `/var/www/html/cytoscape-builds/Cytoscape-3.9.0/<DATE>`

# %%
# !mkdir -p /var/www/html/cytoscape-builds/Cytoscape-3.9.0/rc3
# !rsync -av --progress /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/packaging/target/media/* /var/www/html/cytoscape-builds/Cytoscape-3.9.0/rc3
# !rsync -av --progress /home/cybuilder/cytoscape-admin-scripts/release-build/cytoscape/cytoscape/gui-distribution/assembly/target/*.{gz,zip} /var/www/html/cytoscape-builds/Cytoscape-3.9.0/rc3

# %% [markdown]
# ## 6. Notarizing on idekerlab-macmini
#
# The install4j generated .dmg must be notarized to run on macOS 10.15 and above. The .dmg will be sent to idekerlab-macmini and submitted for notarization. An email will be sent to William Markuske when the notarization process is complete. As soon as the .dmg is notarized it will work and no further action is needed.

# %%
# !rsync -av --progress /var/www/html/cytoscape-builds/Cytoscape-3.9.0/beta1/*.dmg idekerlab@idekerlab-macmini.ucsd.edu:~/apps_to_notarize/
# !ssh idekerlab@idekerlab-macmini.ucsd.edu '~/notarizedmg_jing.sh ~/apps_to_notarize/*.dmg Snapshot.$(date +%Y%m%d)'
# Out:
# building file list ...
# 1 file to consider
# Cytoscape_3_9_0-BETA1_macos.dmg
#     292,914,486 100%  102.43MB/s    0:00:02 (xfr#1, to-chk=0/1)
#
# sent 292,950,394 bytes  received 46 bytes  83,700,125.71 bytes/sec
# total size is 292,914,486  speedup is 1.00
# 2021-07-14 06:51:26.476 altool[10283:130923]  Error:
# [2021-07-14 06:51:18 PDT] <main>  INFO: Configuring logging...
# [2021-07-14 06:51:18 PDT] <main>  INFO: Logging level set to eXtreme
# [2021-07-14 06:51:18 PDT] <main>  INFO: Transporter is searching for new software components.
# [2021-07-14 06:51:18 PDT] <main>  INFO: INFO: using cached repository.xml file.
# [2021-07-14 06:51:19 PDT] <main>  INFO: Update check complete.
# [2021-07-14 06:51:24 PDT] <main> DEBUG: Attempting refresh of configuration data from https://contentdelivery.itunes.apple.com/transporter/Defaults.properties
# [2021-07-14 06:51:24 PDT] <main> DEBUG: Configuration refresh successful.
# [2021-07-14 06:51:24 PDT] <main> DEBUG: Saving configuration to local path: /Users/idekerlab/Library/Caches/com.apple.amp.itmstransporter/Defaults.properties
# [2021-07-14 06:51:24 PDT] <main>  INFO: iTMSTransporter : iTunes Store Transporter [2.1.0]
# [2021-07-14 06:51:24 PDT] <main>  INFO: OS identifier: Mac OS X 10.15.2 (x86_64); jvm=25.71-b02; jre=1.8.0-u131-b11-iTMSTransporter-b02
# [2021-07-14 06:51:24 PDT] <main>  INFO: Memory: [JVM] 997M free, 1087M total, 1820M max [System] (Physical) 720M free, 4096M total (Swap) 0 free, 0 total
# [2021-07-14 06:51:24 PDT] <main>  INFO: Client: altool 4.01 (1182)
# [2021-07-14 06:51:24 PDT] <main>  INFO: Upload mode selected.
# [2021-07-14 06:51:24 PDT] <main> DBG-X: Memory: [JVM] 1055M free, 1102M total, 1820M max [System] (Physical) 709M free, 4096M total (Swap) 0 free, 0 total
# [2021-07-14 06:51:24 PDT] <main> DBG-X: Using operation named: authenticateForTransportDiscovery
# [2021-07-14 06:51:24 PDT] <main> DBG-X: Apple's web service operation input parameters:
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter Application = iTMSTransporter
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter BaseVersion = 1.13.0
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter Client = altool
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter ClientVersion = 4.01 (1182)
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter OSIdentifier = Mac OS X 10.15.2 (x86_64); jvm=25.71-b02; jre=1.8.0-u131-b11-iTMSTransporter-b02
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter StatisticsClientStartDateTimeZoneISO = 2021-07-14T06:51:24-07:00
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter StatisticsPreviousCallDurationInSecs = 0.451230627
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter TransporterArguments = -m upload -u jingjingbic@gmail.com -vp json -DTxHeaders=eyJqZW5nYSI6dHJ1ZX0= -sessionid @env:DD28DB32-9307-4B33-8D31-9F9AC02287F4 -sharedsecret **hidden value** -f /var/folders/py/9t3lv__x7m5708v14cszd0qm0000gn/T/9B22A8F3-D938-4E06-95FD-020630E879DB/Snapshot.20210714.itmsp -indicator true -v eXtreme -Dtransporter.client=altool -Dtransporter.client.version=4.01 (1182)
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter Version = 2.1.0
# [2021-07-14 06:51:24 PDT] <main> DBG-X:   parameter iTMSTransporterMode = upload
# [2021-07-14 06:51:24 PDT] <main>  INFO: id = 20210714065124-712
# [2021-07-14 06:51:25 PDT] <main>  INFO: iTMSTransporter Correlation Key: 9da704a2-714b-419c-adae-3f13160d27cb-0001
# [2021-07-14 06:51:25 PDT] <main> DEBUG: DataCenter: contentdelivery01.itunes.apple.com
# [2021-07-14 06:51:25 PDT] <main> DBG-X: Apple's web service operation return value:
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter EnableJWTForAllCalls = false
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter PreferredTransports = [HTTP, Signiant, Aspera, DAV]
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter TransportHosts.Signiant = [sgr602.apple.com:44001, sgr604.apple.com:44001, sgr603.apple.com:44001, sgr601.apple.com:44001]
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter SessionExpiration = 2021-07-18T13:51:25.292Z
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter TransportHosts.DAV = [itmsdav.apple.com:443]
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter TransportHosts.Aspera = [vgr502.apple.com:33001, vgr503.apple.com:33001, vgr504.apple.com:33001, vgr501.apple.com:33001]
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter ShouldUseRESTAPIs = false
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter StreamingSettings = {LogStreamingEnabled=true, MultipartUploadsEnabled=true, AssetDescriptionStreamingEnabled=false}
# [2021-07-14 06:51:25 PDT] <main>  INFO: Transporter's command line arguments are: -m upload -u jingjingbic@gmail.com -vp json -DTxHeaders=eyJqZW5nYSI6dHJ1ZX0= -sessionid @env:DD28DB32-9307-4B33-8D31-9F9AC02287F4 -sharedsecret **hidden value** -f /var/folders/py/9t3lv__x7m5708v14cszd0qm0000gn/T/9B22A8F3-D938-4E06-95FD-020630E879DB/Snapshot.20210714.itmsp -indicator true -v eXtreme -Dtransporter.client=altool -Dtransporter.client.version=4.01 (1182)
# [2021-07-14 06:51:25 PDT] <main>  INFO: Examining the package at: /var/folders/py/9t3lv__x7m5708v14cszd0qm0000gn/T/9B22A8F3-D938-4E06-95FD-020630E879DB/Snapshot.20210714.itmsp
# [2021-07-14 06:51:25 PDT] <main>  INFO: Ensuring that package has well formed metadata file...
# [2021-07-14 06:51:25 PDT] <main> DEBUG: Getting case-sensitive metadata xml filename...
# [2021-07-14 06:51:25 PDT] <main>  INFO: Gathering the list of valid files from the package ...
# [2021-07-14 06:51:25 PDT] <main> DEBUG:   metadata.xml will be verified by Apple's web service to determine if it is a valid file.
# [2021-07-14 06:51:25 PDT] <main> DEBUG:   Cytoscape_3_9_0-BETA1_macos.dmg will be verified by Apple's web service to determine if it is a valid file.
# [2021-07-14 06:51:25 PDT] <main>  INFO: Finished gathering the list of valid files from the package.
# [2021-07-14 06:51:25 PDT] <main> DEBUG:   Case-sensitive metadata filename is: metadata.xml
# [2021-07-14 06:51:25 PDT] <main>  INFO: JSON:{"msg":{"phase":"Upload","description":"Analyzing metadata","index":0},"messageType":"VerifyProgress"}
# [2021-07-14 06:51:25 PDT] <main>  INFO: Performing authentication of package Snapshot.20210714.itmsp ...
# [2021-07-14 06:51:25 PDT] <main> DBG-X: Memory: [JVM] 1041M free, 1102M total, 1820M max [System] (Physical) 703M free, 4096M total (Swap) 0 free, 0 total
# [2021-07-14 06:51:25 PDT] <main>  INFO: JSON:{"msg":{"phase":"Upload","count":2,"description":"Analyzing metadata","index":1},"messageType":"VerifyProgress"}
# [2021-07-14 06:51:25 PDT] <main> DBG-X: Deflated 550 bytes to 444
# [2021-07-14 06:51:25 PDT] <main> DBG-X: Using operation named: validateMetadata
# [2021-07-14 06:51:25 PDT] <main> DBG-X: Apple's web service operation input parameters:
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Application = iTMSTransporter
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter BaseVersion = 1.13.0
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Client = altool
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter ClientVersion = 4.01 (1182)
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Files = [metadata.xml, Cytoscape_3_9_0-BETA1_macos.dmg]
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Metadata = <?xml version="1.0" encoding="UTF-8"?>
# <package version="software5.9" xmlns="http://apple.com/itunes/importer">
#     <software_assets
#         app_platform="osx"
#         primary_bundle_identifier="Snapshot.20210714">
#         <asset type="developer-id-package">
#             <data_file>
#                 <file_name>Cytoscape_3_9_0-BETA1_macos.dmg</file_name>
#                 <checksum type="md5">9766fd4fd40efe5e5c247c8a21eb7c0a</checksum>
#                 <size>292914486</size>
#             </data_file>
#         </asset>
#     </software_assets>
# </package>
#
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter MetadataChecksum = 5e7559d5c0bb262f8d90a8efcf9ffe61
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter MetadataCompressed = (suppressed)
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter MetadataInfo = {app_platform=osx, primary_bundle_identifier=Snapshot.20210714, device_id=, bundle_identifier=, packageVersion=software5.9, apple_id=, asset_types=[developer-id-package], bundle_version=, bundle_short_version_string=}
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter OSIdentifier = Mac OS X 10.15.2 (x86_64); jvm=25.71-b02; jre=1.8.0-u131-b11-iTMSTransporter-b02
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter PackageName = Snapshot.20210714.itmsp
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter PackageSize = 292915036
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter StatisticsClientStartDateTimeZoneISO = 2021-07-14T06:51:25-07:00
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter TransporterArguments = -m upload -u jingjingbic@gmail.com -vp json -DTxHeaders=eyJqZW5nYSI6dHJ1ZX0= -sessionid @env:DD28DB32-9307-4B33-8D31-9F9AC02287F4 -sharedsecret **hidden value** -f /var/folders/py/9t3lv__x7m5708v14cszd0qm0000gn/T/9B22A8F3-D938-4E06-95FD-020630E879DB/Snapshot.20210714.itmsp -indicator true -v eXtreme -Dtransporter.client=altool -Dtransporter.client.version=4.01 (1182)
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Version = 2.1.0
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter iTMSTransporterMode = upload
# [2021-07-14 06:51:25 PDT] <main>  INFO: id = 20210714065125-850
# [2021-07-14 06:51:25 PDT] <main>  INFO: iTMSTransporter Correlation Key: 9da704a2-714b-419c-adae-3f13160d27cb-0001
# [2021-07-14 06:51:25 PDT] <main> DEBUG: DataCenter: contentdelivery01.itunes.apple.com
# [2021-07-14 06:51:25 PDT] <main> DBG-X: Apple's web service operation return value:
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Errors = [You must first sign the relevant contracts online. (1048)]
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter EnableJWTForAllCalls = false
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter RestartClient = false
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter ErrorCode = 1048
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter ErrorMessage = You must first sign the relevant contracts online. (1048)
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter ShouldUseRESTAPIs = false
# [2021-07-14 06:51:25 PDT] <main> DBG-X:   parameter Success = false
# [2021-07-14 06:51:25 PDT] <main> ERROR: You must first sign the relevant contracts online. (1048)
# [2021-07-14 06:51:25 PDT] <main> DBG-X: The error code is: 1048
# [2021-07-14 06:51:25 PDT] <main>  INFO: JSON:{"msg":{"phase":"Upload","count":2,"description":"Operation failed","index":2},"messageType":"VerifyProgress"}
# [2021-07-14 06:51:26 PDT] <main> DBG-X: Returning 1
# 2021-07-14 06:51:26.576 altool[10283:130923]  Out:
#
#
#
# Package Summary:
#
# 1 package(s) were not uploaded because they had problems:
# 	/var/folders/py/9t3lv__x7m5708v14cszd0qm0000gn/T/9B22A8F3-D938-4E06-95FD-020630E879DB/Snapshot.20210714.itmsp - Error Messages:
# 		You must first sign the relevant contracts online. (1048)
# 2021-07-14 06:51:26.683 altool[10283:130916] *** Error: Unable to notarize app.
# 2021-07-14 06:51:26.683 altool[10283:130916] *** Error: code 1048 (You must first sign the relevant contracts online. (1048))

# %% [markdown]
# You can check the status of the notarization by pasting in the `RequestUUID` value into the following command and running.

# %%
# !ssh idekerlab@idekerlab-macmini.ucsd.edu '~/notarizestatus_jing.sh 6a41ff2a-9fd8-43d6-b378-adfd075b613b'
# Out:
# No errors getting notarization info.
#
#           Date: 2021-04-30 13:56:52 +0000
#           Hash: 7d32053845cd00b39f1a454710f3a650974f7f5d980ea41753a515efb27ee8cc
#     LogFileURL: https://osxapps-ssl.itunes.apple.com/itunes-assets/Enigma115/v4/91/1f/c3/911fc3d0-a26b-067b-633c-b9cc8ce3e71a/developer_log.json?accessKey=1619985924_8906453629669302967_JpRk3DbwQdUPeY0fjgXAfuB0rVc%2FQkGm0wHltInIzu7k9XgkuwZmK3DtsDmyD%2FHD%2FAP1BLjqG%2BlEIEvOJNlbOcYPq%2FKsH%2B5LfUd%2Byja0avqDGmZ15ZgRo4Rp9sOJYsf%2Fv8PydAzkQSHl9NQDC8CfSUg%2BE1%2Fpw47CEbwJpnrmmfQ%3D
#    RequestUUID: 6a41ff2a-9fd8-43d6-b378-adfd075b613b
#         Status: success
#    Status Code: 0
# Status Message: Package Approved
